# %% [markdown]
# # DAT210x - Programming with Python for DS

# %% [markdown]
# ## Module6- Lab5

# %%
import pandas as pd

# %% [markdown]
# Useful information about the dataset used in this assignment can be [found here](https://archive.ics.uci.edu/ml/machine-learning-databases/mushroom/agaricus-lepiota.names).

# %% [markdown]
# Load up the mushroom dataset into dataframe `X` and verify you did it properly, and that you have not included any features that clearly shouldn't be part of the dataset.
#
# You should not have any doubled indices. You can check out information about the headers present in the dataset using the link we provided above. Also make sure you've properly captured any NA values.

# %%
col_names = ["class","f1", "f2", "f3", "f4", "f5", "f6", "f7", "f8", "f9", "f10","f11",
                     "f12","f13","f14","f15","f16","f17","f18","f19","f20","f21","f22"]
X = pd.read_csv("Datasets/agaricus-lepiota.data" ,na_values="?", header=None, names = col_names)
X.head()
# Out:
#   class f1 f2 f3 f4 f5 f6 f7 f8 f9 ... f13 f14 f15 f16 f17 f18 f19 f20 f21 f22
# 0     p  x  s  n  t  p  f  c  n  k ...   s   w   w   p   w   o   p   k   s   u
# 1     e  x  s  y  t  a  f  c  b  k ...   s   w   w   p   w   o   p   n   n   g
# 2     e  b  s  w  t  l  f  c  b  n ...   s   w   w   p   w   o   p   n   n   m
# 3     p  x  y  w  t  p  f  c  n  n ...   s   w   w   p   w   o   p   k   s   u
# 4     e  x  s  g  f  n  f  w  b  k ...   s   w   w   p   w   o   e   n   a   g
#
# [5 rows x 23 columns]

# %%
# An easy way to show which rows have nans in them:
X[pd.isnull(X).any(axis=1)]
# Out:
#      class f1 f2 f3 f4 f5 f6 f7 f8 f9 ... f13 f14 f15 f16 f17 f18 f19 f20 f21  \
# 3984     e  x  y  b  t  n  f  c  b  e ...   s   e   w   p   w   t   e   w   c
# 4023     p  x  y  e  f  y  f  c  n  b ...   s   w   w   p   w   o   e   w   v
# 4076     e  f  y  u  f  n  f  c  n  h ...   f   w   w   p   w   o   f   h   y
# 4100     p  x  y  e  f  y  f  c  n  b ...   s   p   p   p   w   o   e   w   v
# 4104     p  x  y  n  f  f  f  c  n  b ...   s   p   p   p   w   o   e   w   v
# 4196     p  x  y  n  f  y  f  c  n  b ...   k   p   p   p   w   o   e   w   v
# 4200     p  x  y  n  f  y  f  c  n  b ...   k   p   w   p   w   o   e   w   v
# 4283     e  f  s  p  t  n  f  c  b  e ...   s   w   w   p   w   t   e   w   c
# 4291     e  k  s  p  t  n  f  c  b  e ...   s   w   e   p   w   t   e   w   c
# 4326     e  x  y  r  f  n  f  c  n  p ...   f   w   w   p   w   o   f   h   v
# 4329     p  x  y  n  f  s  f  c  n  b ...   s   w   w   p   w   o   e   w   v
# 4331     p  k  y  n  f  n  f  c  n  w ...   y   w   n   p   w   o   e   w   v
# 4357     e  x  s  e  t  n  f  c  b  e ...   s   w   e   p   w   t   e   w   c
# 4376     p  x  y  n  f  y  f  c  n  b ...   k   w   p   p   w   o   e   w   v
# 4380     e  x  y  b  t  n  f  c  b  e ...   s   w   e   p   w   t   e   w   c
# 4396     e  x  y  u  f  n  f  c  n  h ...   f   w   w   p   w   o   f   h   y
# 4419     e  x  s  b  t  n  f  c  b  e ...   s   w   w   p   w   t   e   w   c
# 4429     p  x  y  n  f  y  f  c  n  b ...   s   w   p   p   w   o   e   w   v
# 4459     e  k  y  b  t  n  f  c  b  e ...   s   e   e   p   w   t   e   w   c
# 4461     p  x  y  n  f  s  f  c  n  b ...   k   p   w   p   w   o   e   w   v
# 8118     p  k  y  n  f  f  f  c  n  b ...   s   p   w   p   w   o   e   w   v
# 8119     e  k  s  n  f  n  a  c  b  y ...   s   o   o   p   o   o   p   b   c
# 8120     e  x  s  n  f  n  a  c  b  y ...   s   o   o   p   n   o   p   b   v
# 8121     e  f  s  n  f  n  a  c  b  n ...   s   o   o   p   o   o   p   b   c
# 8122     p  k  y  n  f  y  f  c  n  b ...   k   w   w   p   w   o   e   w   v
# 8123     e  x  s  n  f  n  a  c  b  y ...   s   o   o   p   o   o   p   o   c
#
#      f22
# 3984   w
# 4023   p
# 4076   d
# 4100   d
# 4104   l
# 4196   d
# 4200   l
# 4283   w
# 4291   w
# 4326   d
# 4329   p
# 4331   d
# 4357   w
# 4376   d
# 4380   w
# 4396   d
# 4419   w
# 4429   d
# 4459   w
# 4461   d
# 4494   d
# 4497   w
# 4498   p
# 4519   w
# 4522   l
# 4533   d
# 4534   w
# 4557   d
# 4610   d
# 4611   w
# ...   ..
# 8092   p
# 8093   d
# 8094   g
# 8096   g
# 8097   l
# 8098   d
# 8099   g
# 8100   l
# 8101   p
# 8102   l
# 8103   l
# 8104   l
# 8105   l
# 8106   l
# 8107   l
# 8108   l
# 8109   g
# 8110   l
# 8111   g
# 8112   l
# 8113   d
# 8115   l
# 8116   l
# 8117   d
# 8118   d
# 8119   l
# 8120   l
# 8121   l
# 8122   l
# 8123   l
#
# [2480 rows x 23 columns]

# %% [markdown]
# For this simple assignment, just drop any row with a nan in it, and then print out your dataset's shape:

# %%
X.dropna(axis=0,inplace=True)
X[pd.isnull(X).any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [class, f1, f2, f3, f4, f5, f6, f7, f8, f9, f10, f11, f12, f13, f14, f15, f16, f17, f18, f19, f20, f21, f22]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# Copy the labels out of the dataframe into variable `y`, then remove them from `X`.
#
# Encode the labels, using the `.map()` trick we presented you in Module 5, using `canadian:0`, `kama:1`, and `rosa:2`.

# %%
y = X[["class"]]
X.drop("class",axis=1,inplace=True)

# %% [markdown]
# Encode the entire dataframe using dummies:

# %% [markdown]
# Split your data into `test` and `train` sets. Your `test` size should be 30% with `random_state` 7.
#
# Please use variable names: `X_train`, `X_test`, `y_train`, and `y_test`:

# %%
X = pd.get_dummies(X)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=7)

# %% [markdown]
# Create an DT classifier. No need to set any parameters:

# %%
from sklearn import tree
dtree = tree.DecisionTreeClassifier()

# %% [markdown]
# Train the classifier on the `training` data and labels; then, score the classifier on the `testing` data and labels:

# %%
dtree.fit(X_train, y_train)
score = dtree.score(X_test, y_test)
dtree.tree_.feature
dtree.tree_.node_count
tree.export_graphviz(dtree, out_file='tree.dot', feature_names=X.columns)
from subprocess import call
call(['dot', '-T', 'png', 'tree.dot', '-o', 'tree.png'])
# Out:
# 0

# %%
print("High-Dimensionality Score: ", round((score*100), 3))
# Out:
# High-Dimensionality Score:  100.0

# %% [markdown]
# Use the code on the course's SciKit-Learn page to output a .DOT file, then render the .DOT to .PNGs.
#
# You will need graphviz installed to do this. On macOS, you can `brew install graphviz`. On Windows 10, graphviz installs via a .msi installer that you can download from the graphviz website. Also, a graph editor, gvedit.exe can be used to view the tree directly from the exported tree.dot file without having to issue a call. On other systems, use analogous commands.
#
# If you encounter issues installing graphviz or don't have the rights to, you can always visualize your .dot file on the website: http://webgraphviz.com/.
